# %% [markdown]
# 1.	Store the DNA sequence in a variable called dna and print it to the screen.

# %% [markdown]
# 2.	Print the length of the DNA sequence.

# %% [markdown]
# 3.	Print the first nucleotide in the DNA sequence.

# %% [markdown]
# 4.	Print the last nucleotide in the DNA sequence.

# %% [markdown]
# 5.	Print the first 10 nucleotides of the DNA sequence.

# %% [markdown]
# 6.	Print the last 10 nucleotides of the DNA sequence.

# %% [markdown]
# 7.	Print the nucleotide at position 15 (assume Python indexing).

# %% [markdown]
# 8.	Count and print how many times the nucleotide A appears in the sequence.

# %% [markdown]
# 9.	Count and print how many times T appears in the sequence.

# %% [markdown]
# 10.	Count how many G and C nucleotides occur in total.

# %% [markdown]
# 11.	Print the DNA sequence in lowercase letters.

# %% [markdown]
# 12.	Print the DNA sequence in uppercase letters (even though it already is).

# %% [markdown]
# 13.	Print the sequence three times in a row on the same line.

# %% [markdown]
# 14.	Check whether the substring “TCC” exists in the DNA sequence and print the result.

# %% [markdown]
# 15.	Replace all occurrences of “T” with “U” and print the resulting RNA-like sequence.
